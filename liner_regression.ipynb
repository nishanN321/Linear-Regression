# %% [markdown]
# <a href="https://colab.research.google.com/github/nishanN321/Linear-Regression/blob/main/liner_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import required libraries
import pandas as pd
import seaborn as sns
import matplotlib as plt
import matplotlib.pyplot as plt

# %%
#load dataset
df = sns.load_dataset('diamonds')

# %%
#exploration of the data
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
#creating dummy variable for the catagorical variable
#drop_first to remove first dummy variable to remove dummy variable trap
df_dummy = pd.get_dummies(df, drop_first = True)
df_dummy.head()
# Out:
#    carat  depth  table  price     x     y     z  cut_Premium  cut_Very Good  \
# 0   0.23   61.5   55.0    326  3.95  3.98  2.43        False          False
# 1   0.21   59.8   61.0    326  3.89  3.84  2.31         True          False
# 2   0.23   56.9   65.0    327  4.05  4.07  2.31        False          False
# 3   0.29   62.4   58.0    334  4.20  4.23  2.63         True          False
# 4   0.31   63.3   58.0    335  4.34  4.35  2.75        False          False
#
#    cut_Good  ...  color_H  color_I  color_J  clarity_VVS1  clarity_VVS2  \
# 0     False  ...    False    False    False         False         False
# 1     False  ...    False    False    False         False         False
# 2      True  ...    False    False    False         False         False
# 3     False  ...    False     True    False         False         False
# 4      True  ...    False    False     True         False         False
#
#    clarity_VS1  clarity_VS2  clarity_SI1  clarity_SI2  clarity_I1
# ...

# %%
#correlation matrix to check multicollinearity
cor_matrix = df.corr(numeric_only = True)
sns.heatmap(cor_matrix, cmap = "coolwarm", annot = True, fmt = ".2f")
plt.title("correlation matrix")
plt.show()

# %%
#to define the x and y variables

x = df_dummy.drop('price', axis = 1,)
y = df_dummy['price']

x_numeric = x.select_dtypes(include = [int, float])
x_numeric.head()
# Out:
#    carat  depth  table     x     y     z
# 0   0.23   61.5   55.0  3.95  3.98  2.43
# 1   0.21   59.8   61.0  3.89  3.84  2.31
# 2   0.23   56.9   65.0  4.05  4.07  2.31
# 3   0.29   62.4   58.0  4.20  4.23  2.63
# 4   0.31   63.3   58.0  4.34  4.35  2.75

# %%
#to find the vif for each independent variable (x)
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Make sure x is a DataFrame and contains only numeric values
# (If you've used pd.get_dummies correctly, this should already be true)

# Create a DataFrame to hold VIF values
vif_data = pd.DataFrame()
vif_data["feature"] = x_numeric.columns
vif_data["VIF"] = [variance_inflation_factor(x_numeric.values, i) for i in range(x_numeric.shape[1])]

# Display sorted VIFs
print(vif_data.sort_values("VIF", ascending=False))
# Out:
#   feature          VIF
# 3       x  1284.949828
# 5       z   540.677349
# 4       y   530.998218
# 1   depth   515.146274
# 2   table   500.595341
# 0   carat    70.132799

# %%
df_dummy.drop('x', axis = 1)
x_numeric = x_numeric.drop('x', axis = 1)

# %%
#to find the vif for each independent variable (x)
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Make sure x is a DataFrame and contains only numeric values
# (If you've used pd.get_dummies correctly, this should already be true)

# Create a DataFrame to hold VIF values
vif_data = pd.DataFrame()
vif_data["feature"] = x_numeric.columns
vif_data["VIF"] = [variance_inflation_factor(x_numeric.values, i) for i in range(x_numeric.shape[1])]

# Display sorted VIFs
print(vif_data.sort_values("VIF", ascending=False))
# Out:
#   feature         VIF
# 1   depth  515.092476
# 2   table  436.250123
# 4       z  418.609393
# 3       y  357.472201
# 0   carat   52.260723

# %%
df_dummy.drop('depth', axis = 1)
x_numeric = x_numeric.drop('depth', axis = 1)

# %%
#to find the vif for each independent variable (x)
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Make sure x is a DataFrame and contains only numeric values
# (If you've used pd.get_dummies correctly, this should already be true)

# Create a DataFrame to hold VIF values
vif_data = pd.DataFrame()
vif_data["feature"] = x_numeric.columns
vif_data["VIF"] = [variance_inflation_factor(x_numeric.values, i) for i in range(x_numeric.shape[1])]

# Display sorted VIFs
print(vif_data.sort_values("VIF", ascending=False))
# Out:
#   feature         VIF
# 2       y  357.058944
# 3       z  338.792097
# 1   table  139.077412
# 0   carat   42.417568

# %%
df_dummy.drop('y', axis = 1)
x_numeric = x_numeric.drop('y', axis = 1)

# %%
#to find the vif for each independent variable (x)
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Make sure x is a DataFrame and contains only numeric values
# (If you've used pd.get_dummies correctly, this should already be true)

# Create a DataFrame to hold VIF values
vif_data = pd.DataFrame()
vif_data["feature"] = x_numeric.columns
vif_data["VIF"] = [variance_inflation_factor(x_numeric.values, i) for i in range(x_numeric.shape[1])]

# Display sorted VIFs
print(vif_data.sort_values("VIF", ascending=False))
# Out:
#   feature         VIF
# 2       z  228.757984
# 1   table  106.855430
# 0   carat   33.497953

# %%
df_dummy.drop('z', axis = 1)
x_numeric = x_numeric.drop('z', axis = 1)

# %%
#to find the vif for each independent variable (x)
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Make sure x is a DataFrame and contains only numeric values
# (If you've used pd.get_dummies correctly, this should already be true)

# Create a DataFrame to hold VIF values
vif_data = pd.DataFrame()
vif_data["feature"] = x_numeric.columns
vif_data["VIF"] = [variance_inflation_factor(x_numeric.values, i) for i in range(x_numeric.shape[1])]

# Display sorted VIFs
print(vif_data.sort_values("VIF", ascending=False))
# Out:
#   feature       VIF
# 1   table  3.910114
# 0   carat  3.910114

# %%
x_no_vif = df_dummy.drop(['x','y','z', 'depth', 'price'], axis = 1)
x_no_vif.head()
# Out:
#    carat  table  cut_Premium  cut_Very Good  cut_Good  cut_Fair  color_E  \
# 0   0.23   55.0        False          False     False     False     True
# 1   0.21   61.0         True          False     False     False     True
# 2   0.23   65.0        False          False      True     False     True
# 3   0.29   58.0         True          False     False     False    False
# 4   0.31   58.0        False          False      True     False    False
#
#    color_F  color_G  color_H  color_I  color_J  clarity_VVS1  clarity_VVS2  \
# 0    False    False    False    False    False         False         False
# 1    False    False    False    False    False         False         False
# 2    False    False    False    False    False         False         False
# 3    False    False    False     True    False         False         False
# 4    False    False    False    False     True         False         False
#
#    clarity_VS1  clarity_VS2  clarity_SI1  clarity_SI2  clarity_I1
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x_no_vif, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
import statsmodels.api as sm

# Ensure both X and y are numeric
X_train_sm = sm.add_constant(X_train).astype(float)
y_train_sm = y_train.astype(float)
X_test_sm = sm.add_constant(X_test).astype(float)

# Fit OLS model
ols_model = sm.OLS(y_train_sm, X_train_sm).fit()

# Predict
y_pred_sm = ols_model.predict(X_test_sm)


from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

mse = mean_squared_error(y_test, y_pred_sm)
mae = mean_absolute_error(y_test, y_pred_sm)
r2 = r2_score(y_test, y_pred_sm)

print("📊 Model Evaluation Metrics:")
print(f"Mean Squared Error: {mse:.2f}")
print(f"Mean Absolute Error: {mae:.2f}")
print(f"R² Score: {r2:.4f}\n")

# Show t-test and F-test in regression summary
print("🧪 Regression Summary (with t-tests and F-test):")
print(ols_model.summary())
# Out:
# 📊 Model Evaluation Metrics:
# Mean Squared Error: 1345503.99
# Mean Absolute Error: 801.63
# R² Score: 0.9154
#
# 🧪 Regression Summary (with t-tests and F-test):
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.916
# Model:                            OLS   Adj. R-squared:                  0.916
# Method:                 Least Squares   F-statistic:                 2.481e+04
# Date:                Tue, 05 Aug 2025   Prob (F-statistic):               0.00
# Time:                        09:07:07   Log-Likelihood:            -3.6554e+05
# No. Observations:               43152   AIC:                         7.311e+05
# Df Residuals:                   43132   BIC:                         7.313e+05
# Df Model:                          19
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
import pandas as pd

coefficients = pd.Series(model.coef_, index=X_train.columns)
print(coefficients.sort_values(ascending=False))
# Out:
# carat            8906.434160
# table             -19.217094
# cut_Premium       -83.651920
# cut_Very Good    -114.561780
# color_E          -217.460929
# cut_Good         -304.122762
# color_F          -308.681892
# clarity_VVS1     -359.365183
# clarity_VVS2     -464.804662
# color_G          -521.341467
# clarity_VS1      -903.501768
# cut_Fair         -965.320886
# color_H          -995.592162
# clarity_VS2     -1225.542831
# color_I         -1453.910043
# clarity_SI1     -1852.918533
# color_J         -2329.187743
# clarity_SI2     -2809.666208
# clarity_I1      -5440.543386
# dtype: float64

# %%
#to check relationship between actual and predicted value
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, alpha=0.5, color='blue')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', linewidth=2)  # diagonal line

plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual vs Predicted Diamond Prices")
plt.grid(True)
plt.show()

# %%
#relationship between error and predicted values
import matplotlib.pyplot as plt

# Calculate residuals
residuals = y_test - y_pred

# Scatter plot: Predicted vs Residuals
plt.figure(figsize=(8, 6))
plt.scatter(y_pred, residuals, alpha=0.5, color='purple')
plt.axhline(y=0, color='red', linestyle='--', linewidth=2)

plt.xlabel("Predicted Price")
plt.ylabel("Residuals (Actual - Predicted)")
plt.title("Residuals vs Predicted Values")
plt.grid(True)
plt.show()

# %%
x_no_vif.head()
# Out:
#    carat  table  cut_Premium  cut_Very Good  cut_Good  cut_Fair  color_E  \
# 0   0.23   55.0        False          False     False     False     True
# 1   0.21   61.0         True          False     False     False     True
# 2   0.23   65.0        False          False      True     False     True
# 3   0.29   58.0         True          False     False     False    False
# 4   0.31   58.0        False          False      True     False    False
#
#    color_F  color_G  color_H  color_I  color_J  clarity_VVS1  clarity_VVS2  \
# 0    False    False    False    False    False         False         False
# 1    False    False    False    False    False         False         False
# 2    False    False    False    False    False         False         False
# 3    False    False    False     True    False         False         False
# 4    False    False    False    False     True         False         False
#
#    clarity_VS1  clarity_VS2  clarity_SI1  clarity_SI2  clarity_I1
# ...

# %%
columns = x_no_vif.columns.tolist()
print(columns)
# Out:
# ['carat', 'table', 'cut_Premium', 'cut_Very Good', 'cut_Good', 'cut_Fair', 'color_E', 'color_F', 'color_G', 'color_H', 'color_I', 'color_J', 'clarity_VVS1', 'clarity_VVS2', 'clarity_VS1', 'clarity_VS2', 'clarity_SI1', 'clarity_SI2', 'clarity_I1']

# %%
feature_columns = X_train.columns.tolist()

# %%
# Input values in the exact same order as feature_columns
input_list = [[
    0.5, 95.0,        # carat, table
    0, 1, 0, 0,       # cut: Premium
    1, 0, 0, 0, 0 , 0, # color: I
    0, 0, 0, 1, 0, 0, 0  # clarity: VS2
]]

# Predict and clip negative values to 0
predicted_price = max(0, model.predict(input_list)[0])

# Correct print statement
print(f" Predicted Diamond Price: ${predicted_price:.2f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-322757804.py in <cell line: 0>()
#       8
#       9 # Predict and clip negative values to 0
# ---> 10 predicted_price = max(0, model.predict(input_list)[0])
#      11
#      12 # Correct print statement
#
# NameError: name 'model' is not defined

# %%
plt.hist(df['carat'])
plt.show()

# %%
plt.boxplot(df['carat'])
plt.show()

# %%
df['carat'].describe()
# Out:
# count    53940.000000
# mean         0.797940
# std          0.474011
# min          0.200000
# 25%          0.400000
# 50%          0.700000
# 75%          1.040000
# max          5.010000
# Name: carat, dtype: float64
